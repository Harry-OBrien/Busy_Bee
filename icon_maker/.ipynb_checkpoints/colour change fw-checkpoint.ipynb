# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
# Thresholding value
t_val = 200

# Output colours
colours = {
    "red":np.array([64, 80, 217]),
    "amber":np.array([66, 189, 242]),
    "green":np.array([92, 165, 88]),
    "black":np.array([0, 0, 0]),
}

# %%
# Import the image
colour_icon = (cv2.cvtColor(cv2.imread("./bee_pub.png"), cv2.COLOR_BGR2RGB)).astype(np.uint8)

# %%
def show_colour_image(img, save_img_name=None):
    if save_img_name != None:
        cv2.imwrite('img_out/' + save_img_name + '.jpg', img)
    
    plt.imshow(img, vmin=0, vmax=255)
    plt.axis('off')
    plt.show()
    
show_colour_image(colour_icon)  

# red = [
#     [230,   0,   0],
#     [232,  83,  86],
#     [232,  69,  72],
#     [232,  70,  74]]

# green = [
#     [246 252 247],
#     [133 216 131],
#     [117 211 112],
#     [123 213 119],
#     [121 212 117]]


# yellow = [247 210  84]

# white = [255,255,255]

# %%
# Swap the thresheld values for the input colours
def swap_colours(img, r_replace, g_replace, y_replace, w_replace=0):
    
    output_img = np.full((*img.shape, 4), w_replace, dtype=np.uint8)
    for i, row in enumerate(img):
        for j, pix in enumerate(row):
            r, g, b = pix
            if r > 200:
                out_img[i, j] = 
            
            
            
            
#             if pix[1] > 200:
#                 # for key in colours.keys():
#                 output_img[i,j] = colours["red"]
#             elif pix[2] > 200:
#                 # for key in colours.keys():
#                 output_img[i,j] = colours["green"]

swap_colours(colour_icon)
# Out:
# 255

# %%
# Write out the images
# for key, img_out in output_images.items():
# print(output_img)
# cv2.imwrite('bee_pub_mixed.jpg', output_img)
